# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Probabilidade - Tarefa

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math
import seaborn as sns
import matplotlib.ticker as mtick

from scipy.stats import norm, t

# %% [markdown]
# 1. Uma máquina embala ração para cachorro em pacotes de 15 kg, mas cada pacote produzido acaba tendo um peso aleatório, com distribuição Normal, com média 15kg, mas com desvio padrão 0,1 kg. Obtenha a probabilidade de que um pacote selecionado aleatoriamente dessa produção tenha mais que 15,2 kg.

# %%
media = 15
desvio_padrao = 0.1

peso_limite = 15.2

prob = norm.sf(peso_limite, loc=media, scale=desvio_padrao)
print(f"Probabilidade de pesar mais de 15,2 kg: {prob:.4f}")
# Out:
# Probabilidade de pesar mais de 15,2 kg: 0.0228

# %% [markdown]
# 2. Da máquina descrita acima, obtenha o percentil de ordem 95% para o peso dos pacotes. Ou seja, o valor tal que a probabilidade de um pacote ter peso menor que este seja de 95%.

# %%
media = 15
desvio_padrao = 0.1

percentil_95 = norm.ppf(0.95, loc=media, scale=desvio_padrao)

print(f"Percentil 95%: {percentil_95:.4f} kg")
# Out:
# Percentil 95%: 15.1645 kg

# %% [markdown]
# 3. Suponha duas variáveis aleatórias $Y_1$ e $Y_2$, a primeira com distribuição Normal Padrão (média=0, variância=1), a segunda com distribuição *t-studdent* com 5 graus de liberdade (também padrão). Calcule, para cada uma, a probabilidade de ser menor que cada um dos valores contidos no objeto $Y$ na célula abaixo:

# %%
Y=np.linspace(-6, 6, 200)
# Seu código começa aqui

prob_normal = norm.cdf(Y, loc=0, scale=1)

prob_tstudent = t.cdf(Y, df=5)

print("Primeiras probabilidades (Normal):", prob_normal[:5])
print("Primeiras probabilidades (t-student):", prob_tstudent[:5])
# Out:
# Primeiras probabilidades (Normal): [9.86587645e-10 1.42773376e-09 2.05881881e-09 2.95834659e-09
#  4.23585138e-09]
# Primeiras probabilidades (t-student): [0.00092307 0.00096571 0.00101068 0.00105814 0.00110824]

# %% [markdown]
# 4. Faça uma visualização gráfica dos dados do item anterior.

# %%
plt.plot(Y, prob_normal, label='Normal Padrão')
plt.plot(Y, prob_tstudent, label='t-student (df=5)')
plt.xlabel('Y')
plt.ylabel('Probabilidade acumulada')
plt.title('Função de Distribuição Acumulada (CDF)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 5. 3. Suponha duas variáveis aleatórias $Y_1$ e $Y_2$, a primeira com distribuição Normal Padrão (média=0, variância=1), a segunda com distribuição *t-studdent* com 5 graus de liberdade (também padrão). Calcule, para cada uma, o percentil (a inversa da *CDF*) para cada um dos valores do objeto *P* abaixo:

# %%
P=np.linspace(0, 1, 20)
# Seu código começa aqui

percentil_normal = norm.ppf(P, loc=0, scale=1)

percentil_tstudent = t.ppf(P, df=5)

print("Percentis Normal:", percentil_normal)
print("Percentis t-student:", percentil_tstudent)
# Out:
# Percentis Normal: [       -inf -1.61985626 -1.25211952 -1.00314797 -0.80459638 -0.63364
#  -0.47950565 -0.33603814 -0.19920132 -0.06601181  0.06601181  0.19920132
#   0.33603814  0.47950565  0.63364     0.80459638  1.00314797  1.25211952
#   1.61985626         inf]
# Percentis t-student: [       -inf -1.97489346 -1.4358593  -1.11439619 -0.87612441 -0.68067217
#  -0.51027663 -0.35532778 -0.20979907 -0.06939058  0.06939058  0.20979907
#   0.35532778  0.51027663  0.68067217  0.87612441  1.11439619  1.4358593
#   1.97489346         inf]

# %% [markdown]
# 6. Faça um gráfico com os dados do item anterior.

# %%
plt.plot(P, percentil_normal, label="Normal padrão")
plt.plot(P, percentil_tstudent, label="t-student (df=5)")
plt.xlabel("Probabilidade (P)")
plt.ylabel("Percentil (valor de Y)")
plt.title("Percentis das distribuições")
plt.legend()
plt.grid(True)
plt.show()
